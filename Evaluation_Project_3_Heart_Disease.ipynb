# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Summary

# %% [markdown]
# The below datset have attributes realating to patients and we will be classifying and make a model which will help in predicting if patients have heart disease or not.

# %% [markdown]
# ### Columnal Description

# %% [raw]
# age - age in years
# sex - (1 = male; 0 = female)
# cp - chest pain type
# trestbps - resting blood pressure (in mm Hg on admission to the hospital)
# chol - serum cholestoral in mg/dl
# fbs - (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# restecg - resting electrocardiographic results
# thalach - maximum heart rate achieved
# exang - exercise induced angina (1 = yes; 0 = no)
# oldpeak - ST depression induced by exercise relative to rest
# slope - the slope of the peak exercise ST segment
# ca - number of major vessels (0-3) colored by flourosopy
# thal - 3 = normal; 6 = fixed defect; 7 = reversable defect
# target - have disease or not (1=yes, 0=no)

# %% [markdown]
# ### Calling DataFrame

# %%
#calling he entire dataset
ds_heart=pd.read_csv("Heart.csv")
ds_heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ### Describing Information

# %%
#describing information relating to he dataset
ds_heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [raw]
# Observations:
#
# 1) There are 13 numeric columns
#
# 2) There is 1 float column in the dataset.

# %% [markdown]
# ### Plotting Missing Values

# %%
ds_heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#plotting Null Values in a Heatmap
sns.heatmap(ds_heart.isnull())

# %% [raw]
# Observations:
#
# No null values in the dataset

# %% [markdown]
# ### Describing Statistics

# %%
ds_heart.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [raw]
# Observations:
#
# 1) For the columns like chol, exang, old peak and  where the mean is more  than the median, the data must be rightly skewed. We will fix it.
#
# 2) The max for column chol, ca, oldpeak is way more than the 75% of the data so that means there must be outliers present. We will later fix it using z-score.
#
# 3) The maximum age in the datset is 77 and minimum being 29.

# %% [markdown]
# ### Plotting Co-relation

# %%
#plotting co-relation to find reration of one variable to the other.
ds_heart.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# target   -0.225439 -0.280937  0.433798 -0.144931 -0.085239 -0.028046
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.116211 -0.398522  0.096801  0.210013 -0.168814  0.276326
# sex      -0.058196 -0.044020  0.141664  0.096093 -0.030711  0.118261
# cp        0.044421  0.295762 -0.394280 -0.149230  0.119717 -0.181053
# trestbps -0.114103 -0.046698  0.067616  0.193216 -0.121475  0.101389
# chol     -0.151040 -0.009940  0.067023  0.053952 -0.004038  0.070511
# fbs      -0.084189 -0.008567  0.025665  0.005747 -0.059894  0.137979
# restecg   1.000000  0.044123 -0.070733 -0.058770  0.093045 -0.072042
# thalach   0.044123  1.000000 -0.378812 -0.344187  0.386784 -0.213177
# exang    -0.070733 -0.378812  1.000000  0.288223 -0.257748  0.115739
# oldpeak  -0.058770 -0.344187  0.288223  1.000000 -0.577537  0.222682
# slope     0.093045  0.386784 -0.257748 -0.577537  1.000000 -0.080155
# ca       -0.072042 -0.213177  0.115739  0.222682 -0.080155  1.000000
# thal     -0.011981 -0.096439  0.206754  0.210244 -0.104764  0.151832
# target    0.137230  0.421741 -0.436757 -0.430696  0.345877 -0.391724
#
#               thal    target
# age       0.068001 -0.225439
# sex       0.210041 -0.280937
# cp       -0.161736  0.433798
# trestbps  0.062210 -0.144931
# chol      0.098803 -0.085239
# fbs      -0.032019 -0.028046
# restecg  -0.011981  0.137230
# thalach  -0.096439  0.421741
# exang     0.206754 -0.436757
# oldpeak   0.210244 -0.430696
# slope    -0.104764  0.345877
# ca        0.151832 -0.391724
# thal      1.000000 -0.344029
# target   -0.344029  1.000000

# %%
#plotting correlation in a heatmap.
corr_hmap=ds_heart.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %% [raw]
# Observation:
#
# 1) The above data shows co-relation of each variable with the other.
#
# 2) The columns cp, restecg, thalach and slope are  positively co-related to the target variable, while age, sex tresbps, chol, fbs, exang, oldpeak, ca and thal are negatively co-related.

# %% [markdown]
# ### Univariate  Analysis

# %%
#plotting the age distribution of the dataset in the countplot
plt.figure(figsize=(12,4))
sns.countplot(x="age",data=ds_heart)

# %% [raw]
# Observations:
#
# The datset contains people with age group between 29 to 77. The maximum number of people in the dataset is of age 58.

# %%
#plotting types of chest pain and the number of people having  them over a countplot. 
plt.figure(figsize=(6,4))
sns.countplot(x="cp",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows the various types of chest pains. Most people have type0 chest pain followed by type2 with type3 being the lowest.

# %%
#plotting the ratio of males to females in the datset 
plt.figure(figsize=(6,4))
sns.countplot(x="sex",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows the dataset contain more number of males than compared to females.

# %%
#plotting the distribution of blood pressure level in a violin plot
sns.violinplot(x="trestbps",data=ds_heart)

# %% [raw]
# Observations:
#
# Most people have blood pressure randing from 120 to 140.

# %%
#plotting the distribution of cholestrol level in a violin plot
sns.violinplot(x="chol",data=ds_heart)

# %% [raw]
# Observations:
#
# Most people have blood pressure ranging from 200 to 300.

# %%
#plotting the blood sugar level in a countblot.
plt.figure(figsize=(6,4))
sns.countplot(x="fbs",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows fasting blood sugar level > 120 mg/dl where 1 = true and 0 = false. We have more 0 than 1 in the dataset.

# %%
#plotting the electro cardiographic results in a countplot.
plt.figure(figsize=(6,4))
sns.countplot(x="restecg",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows cardiographic results in a countplot. The number of  0 and 1 type results have equal number of patients while result 2 being the lowest.

# %%
#plotting the distribution of heart rate in a violin plot
sns.violinplot(x="thalach",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows most people have heart rate ranging from 140 to 180.

# %%
#plotting the electro cardiographic results in a countplot.
plt.figure(figsize=(6,4))
sns.countplot(x="exang",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows the datset have more 0s in the cardiographic result compared to 1s.

# %%
#plotting the distribution of result of oldpeak  in a violin plot
sns.violinplot(x="oldpeak",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows dataset have more people with result ranging from -0.05 to +0.05

# %%
#plotting the result of peak exercise segment in a countplot.
plt.figure(figsize=(6,4))
sns.countplot(x="slope",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows results of peak exercise column. Type1 and Type2 almost have the same counts with Type0 being the lowest.

# %%
#plotting the results of major vessels in a countplot.
plt.figure(figsize=(6,4))
sns.countplot(x="ca",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows number of major vessels in of the patients with most peiople having 0 to the least people having 4.

# %%
#plotting the results of defects in a countplot.
plt.figure(figsize=(6,4))
sns.countplot(x="thal",data=ds_heart)

# %% [raw]
# Observations:
#
# The above diagram shows number of defects  where 3 = normal, 6 = fixed defect and 7 = reversable defect. The entire datset is under 3 with 2 being the highest.

# %% [markdown]
# ### Bivariate Analysis

# %%
#plotting the target variable according to the age group
plt.figure(figsize=(20,6))
sns.countplot(data=ds_heart,x="age",hue="target")
plt.show()

# %% [raw]
# Observations:
#
# The above diagram shows the age distribution with people either having a heart disease or not.

# %%
#plotting the target variable according to the sex in the dataset
plt.figure(figsize=(6,4))
sns.countplot(data=ds_heart,x="sex",hue="target")
plt.show()

# %% [raw]
# Observations:
#
# The above diagram shows the dataset have more males compared to females with result 1 in the target variable.

# %%
#plotting the target variable according to the chest pain types in the dataset
plt.figure(figsize=(6,4))
sns.countplot(data=ds_heart,x="cp",hue="target")
plt.show()

# %% [raw]
# Observations:
#
# According to the above diagram the most number of people having an heart disease belongs to chest pain type2.

# %%
#plotting the target variable according to sugar level in a count plot
plt.figure(figsize=(5,4))
sns.countplot(data=ds_heart,x="fbs",hue="target")
plt.show()

# %% [raw]
# Observations:
#
# People with lesser sugar level have higher chances of the disease.

# %%
#plotting the age group of people according to the level of blood pressure
plt.figure(figsize=(5,4))
sns.scatterplot(data=ds_heart,x="age",y="trestbps")
plt.show()

# %%
#plotting the age group of people according to the level of cholestrol
plt.figure(figsize=(5,4))
sns.scatterplot(data=ds_heart,x="chol",y="age")
plt.show()

# %%
#plotting the target variable according to exercise
plt.figure(figsize=(5,4))
sns.countplot(data=ds_heart,x="exang",hue="target")
plt.show()

# %% [raw]
# Observations:
#
# The above diagram shows people with no exercise have more chances of the disease.

# %%
#plotting realtionship of all the variables in a pairplot
sns.pairplot(ds_heart)

# %% [markdown]
# ### Seperating target and input variable

# %%
#splitting the data into target and input variable for the regression study  
ds_heart_x=ds_heart.drop(columns="target")
y=pd.DataFrame(ds_heart["target"])

# %%
#calling input variable 
ds_heart_x
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# 3        2   0     2
# 4        2   0     2
# ..     ...  ..   ...
# 298      1   0     3
# 299      1   0     3
# 300      1   2     3
# 301      1   1     3
# 302      1   1     2
#
# [303 rows x 13 columns]

# %%
#calling target variable
y
# Out:
#      target
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 298       0
# 299       0
# 300       0
# 301       0
# 302       0
#
# [303 rows x 1 columns]

# %% [markdown]
# ### Plotting Outliers

# %%
#plotting all the variables in a boxplot to find 
for i in ds_heart_x.columns:
    plt.figure()
    sns.boxplot(ds_heart_x[i])

# %%
#plotting outliers for all the variables in a single view format for a better understanding
collist=ds_heart_x.columns.values
ncol=17
nrow=10
plt.figure(figsize=(30,50))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(ds_heart[collist[i]],color="green",orient="v")
    plt.tight_layout()

# %% [raw]
# Observations:
#
# We have very less ouliers according to the above diagram so we wont remove them and will take them in the final model.

# %% [markdown]
# ### Plotting Distribution

# %%
#plotting distribution of the variabels in the dataset
sns.distplot(ds_heart_x["trestbps"])

# %%
sns.distplot(ds_heart_x["chol"])

# %%
sns.distplot(ds_heart_x["thalach"])

# %%
sns.distplot(ds_heart_x["oldpeak"])

# %% [markdown]
# ### Checking Skewness

# %%
ds_heart_x.skew()
# Out:
# age        -0.202463
# sex        -0.791335
# cp          0.484732
# trestbps    0.713768
# chol        1.143401
# fbs         1.986652
# restecg     0.162522
# thalach    -0.537410
# exang       0.742532
# oldpeak     1.269720
# slope      -0.508316
# ca          1.310422
# thal       -0.476722
# dtype: float64

# %% [markdown]
# ### Log Transformation

# %%
#using log transformation technique to reduce data skewness
for i in ds_heart_x.columns:
    if ds_heart_x[i].skew()>.55:
        ds_heart_x[i]=np.log1p(ds_heart_x[i])

# %% [markdown]
# ### Rechecking Skewness

# %%
ds_heart_x.skew()
# Out:
# age        -0.202463
# sex        -0.791335
# cp          0.484732
# trestbps    0.284837
# chol        0.090242
# fbs         1.986652
# restecg     0.162522
# thalach    -0.537410
# exang       0.742532
# oldpeak     0.396825
# slope      -0.508316
# ca          0.757752
# thal       -0.476722
# dtype: float64

# %% [markdown]
# ### Scaling the Input Variables

# %%
#using standard scaler to scale input variables
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(ds_heart_x)
x=pd.DataFrame(x,columns=ds_heart_x.columns)
x
# Out:
#           age       sex        cp  trestbps      chol       fbs   restecg  \
# 0    0.952197  0.681005  1.973123  0.810207 -0.169857  2.394438 -1.005832
# 1   -1.915313  0.681005  1.002577 -0.030196  0.176273 -0.417635  0.898962
# 2   -1.474158 -1.468418  0.032031 -0.030196 -0.822868 -0.417635 -1.005832
# 3    0.180175  0.681005  0.032031 -0.645768 -0.106985 -0.417635  0.898962
# 4    0.290464 -1.468418 -0.938515 -0.645768  1.887209 -0.417635  0.898962
# ..        ...       ...       ...       ...       ...       ...       ...
# 298  0.290464 -1.468418 -0.938515  0.540071 -0.003945 -0.417635  0.898962
# 299 -1.033002  0.681005  1.973123 -1.314469  0.444152 -0.417635  0.898962
# 300  1.503641  0.681005 -0.938515  0.756928 -1.095066  2.394438  0.898962
# 301  0.290464  0.681005 -0.938515 -0.030196 -2.995480 -0.417635  0.898962
# 302  0.290464 -1.468418  0.032031 -0.030196 -0.106985 -0.417635 -1.005832
#
#       thalach     exang   oldpeak     slope        ca      thal
# 0    0.015443 -0.696631  1.192005 -2.274579 -0.792785 -2.148873
# 1    1.633471 -0.696631  1.784504 -2.274579 -0.792785 -0.512922
# 2    0.977514 -0.696631  0.583653  0.976352 -0.792785 -0.512922
# 3    1.239897 -0.696631  0.034085  0.976352 -0.792785 -0.512922
# 4    0.583939  1.435481 -0.190919  0.976352 -0.792785 -0.512922
# ..        ...       ...       ...       ...       ...       ...
# 298 -1.165281  1.435481 -0.740487 -0.649113 -0.792785  1.123029
# 299 -0.771706 -0.696631  0.417433 -0.649113 -0.792785  1.123029
# 300 -0.378132 -0.696631  1.741573 -0.649113  1.360200  1.123029
# 301 -1.515125  1.435481  0.417433 -0.649113  0.565597  1.123029
# 302  1.064975 -0.696631 -1.088782 -0.649113  0.565597 -0.512922
#
# [303 rows x 13 columns]

# %% [markdown]
# ### Seperating Training and Testing data

# %%
#using train_test_split to seperate training and testing data
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (242, 13)
# (61, 13)
# (242, 1)
# (61, 1)

# %% [markdown]
# ### Importing Classification Algorithims and Metrices

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %% [markdown]
# ### Putting Aliases

# %%
knn=KNeighborsClassifier()
svc=SVC()
lr=LogisticRegression()
dtc=DecisionTreeClassifier()
gnb=GaussianNB()
rfc=RandomForestClassifier()
gbc=GradientBoostingClassifier()
abc=AdaBoostClassifier()
etc=ExtraTreesClassifier()

# %% [markdown]
# ### Appending Models

# %%
models = []
models.append(('KNeighborsClassifier',knn))
models.append(('SVC',svc))
models.append(('LogisticRegression',lr))
models.append(('DecisionTreeClassifier',dtc))
models.append(('GaussianNB',gnb))
models.append(('RandomForestClassifier',rfc))
models.append(('GradientBoostingClassifier',gbc))
models.append(('ExtraTreesClassifier',etc))
models.append(('AdaBoostClassifier',abc))

# %% [markdown]
# ### Machine Learning

# %%
Model=[]
score=[]
cvs=[]
rocscore=[]
for name,model in models:
    print("*******************",name,"*********************")
    print("\n")
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pred=model.predict(x_test)
    print("\n")
    AS=accuracy_score(y_test,pred)
    print("Accuracy_score=",AS)
    score.append(AS*100)
    print("\n")
    sc= cross_val_score(model,x,y,cv=10,scoring="accuracy").mean()
    print("Cross_val_score=",sc)
    cvs.append(sc*100)
    print("\n")
    false_positive_rate,true_positive_rate,thresholds=roc_curve(y_test,pred)
    roc_auc=auc(false_positive_rate,true_positive_rate)
    print("roc_auc_score=",roc_auc)
    rocscore.append(roc_auc*100)
    print("\n")
    print("classification_report\n",classification_report(y_test,pred))
    print("\n")
    cm=confusion_matrix(y_test,pred)
    print(cm)
    print("\n")
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label="AUC=%0.2f"% roc_auc)
    plt.plot([0,1],[0,1],"r--")
    plt.legend(loc="lower right")
    plt.ylabel("True Positive Rate")
    plt.xlabel("False Positive Rate")
    print("\n\n")
# Out:
# ******************* KNeighborsClassifier *********************
#
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
#
#
# Accuracy_score= 0.8688524590163934
#
#
# Cross_val_score= 0.8183870967741935
#
#
# roc_auc_score= 0.8685344827586206
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        29
#            1       0.88      0.88      0.88        32
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.87      0.87      0.87        61
#
#
#
# [[25  4]
#  [ 4 28]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ******************* SVC *********************
#
#
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
#
#
# Accuracy_score= 0.8524590163934426
#
#
# Cross_val_score= 0.8478494623655914
#
#
# roc_auc_score= 0.8529094827586207
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85        29
#            1       0.87      0.84      0.86        32
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.85      0.85        61
# weighted avg       0.85      0.85      0.85        61
#
#
#
# [[25  4]
#  [ 5 27]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ******************* LogisticRegression *********************
#
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
# Accuracy_score= 0.8688524590163934
#
#
# Cross_val_score= 0.8250537634408603
#
#
# roc_auc_score= 0.8685344827586206
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        29
#            1       0.88      0.88      0.88        32
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.87      0.87      0.87        61
#
#
#
# [[25  4]
#  [ 4 28]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ******************* DecisionTreeClassifier *********************
#
#
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')
#
#
# Accuracy_score= 0.819672131147541
#
#
# Cross_val_score= 0.7616129032258065
#
#
# roc_auc_score= 0.8232758620689656
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.76      0.90      0.83        29
#            1       0.89      0.75      0.81        32
#
#     accuracy                           0.82        61
#    macro avg       0.83      0.82      0.82        61
# weighted avg       0.83      0.82      0.82        61
#
#
#
# [[26  3]
#  [ 8 24]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ******************* GaussianNB *********************
#
#
# GaussianNB(priors=None, var_smoothing=1e-09)
#
#
# Accuracy_score= 0.8852459016393442
#
#
# Cross_val_score= 0.8218279569892474
#
#
# roc_auc_score= 0.8857758620689655
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88        29
#            1       0.90      0.88      0.89        32
#
#     accuracy                           0.89        61
#    macro avg       0.88      0.89      0.89        61
# weighted avg       0.89      0.89      0.89        61
#
#
#
# [[26  3]
#  [ 4 28]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ******************* RandomForestClassifier *********************
#
#
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
#
# Accuracy_score= 0.8360655737704918
#
#
# Cross_val_score= 0.8347311827956989
#
#
# roc_auc_score= 0.8372844827586207
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83        29
#            1       0.87      0.81      0.84        32
#
#     accuracy                           0.84        61
#    macro avg       0.84      0.84      0.84        61
# weighted avg       0.84      0.84      0.84        61
#
#
#
# [[25  4]
#  [ 6 26]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ******************* GradientBoostingClassifier *********************
#
#
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)
#
#
# Accuracy_score= 0.7704918032786885
#
#
# Cross_val_score= 0.8047311827956989
#
#
# roc_auc_score= 0.771551724137931
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.74      0.79      0.77        29
#            1       0.80      0.75      0.77        32
#
#     accuracy                           0.77        61
#    macro avg       0.77      0.77      0.77        61
# weighted avg       0.77      0.77      0.77        61
#
#
#
# [[23  6]
#  [ 8 24]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ******************* ExtraTreesClassifier *********************
#
#
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)
#
#
# Accuracy_score= 0.8524590163934426
#
#
# Cross_val_score= 0.8248387096774193
#
#
# roc_auc_score= 0.8529094827586207
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85        29
#            1       0.87      0.84      0.86        32
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.85      0.85        61
# weighted avg       0.85      0.85      0.85        61
#
#
#
# [[25  4]
#  [ 5 27]]
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# ******************* AdaBoostClassifier *********************
#
#
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=None)
#
#
# Accuracy_score= 0.8032786885245902
#
#
# Cross_val_score= 0.8112903225806452
#
#
# roc_auc_score= 0.8060344827586207
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.76      0.86      0.81        29
#            1       0.86      0.75      0.80        32
#
#     accuracy                           0.80        61
#    macro avg       0.81      0.81      0.80        61
# weighted avg       0.81      0.80      0.80        61
#
#
#
# [[25  4]
#  [ 8 24]]
# AxesSubplot(0.125,0.808774;0.62x0.0712264)

# %% [markdown]
# ### Comparing Models

# %%
results=pd.DataFrame({"Model":Model,"Accuracy_Score":score,"Cross_Val_Score":cvs,"Roc_Auc_Score":rocscore})
results
# Out:
#                         Model  Accuracy_Score  Cross_Val_Score  Roc_Auc_Score
# 0        KNeighborsClassifier       86.885246        81.838710      86.853448
# 1                         SVC       85.245902        84.784946      85.290948
# 2          LogisticRegression       86.885246        82.505376      86.853448
# 3      DecisionTreeClassifier       81.967213        76.161290      82.327586
# 4                  GaussianNB       88.524590        82.182796      88.577586
# 5      RandomForestClassifier       83.606557        83.473118      83.728448
# 6  GradientBoostingClassifier       77.049180        80.473118      77.155172
# 7        ExtraTreesClassifier       85.245902        82.483871      85.290948
# 8          AdaBoostClassifier       80.327869        81.129032      80.603448

# %% [raw]
# Observation:
#
# We will be finalizing Gaussian NB for this dataset as it gives the best result.

# %% [markdown]
# ### Hyper Parameter Tuning

# %% [markdown]
# GaussianNB has no hyperparameter to tune so we will not do anything for it and will finalize the model.

# %% [markdown]
# ### Saving Model

# %%
import joblib
joblib.dump(gnb,"Model_Heart_Disease_gnb.csv")
# Out:
# ['Model_Heart_Disease_gnb.csv']

# %% [markdown]
# ### Loading Model

# %%
Model_Heart_Disease=joblib.load("Model_Heart_Disease_gnb.csv")

# %% [markdown]
# ### Using Model

# %%
pd.DataFrame(Model_Heart_Disease.predict(x_test))
# Out:
#     0
# 0   0
# 1   1
# 2   1
# 3   0
# 4   1
# .. ..
# 56  0
# 57  1
# 58  0
# 59  0
# 60  0
#
# [61 rows x 1 columns]
